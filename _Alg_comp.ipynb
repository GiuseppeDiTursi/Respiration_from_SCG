# %% [markdown]
# # IMPORTING LIBRARIES

# %%
import pickle
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import numpy as np

# %% [markdown]
# # DATA LOADING

# %%
with open("/home/giuseppeditursi/Desktop/Respiration_from_SCG/2_Resp_Extraction/0_ICA/ICA_err_all", "rb") as fp:   # Unpickling
    ICA_err_all = pickle.load(fp)

with open("/home/giuseppeditursi/Desktop/Respiration_from_SCG/2_Resp_Extraction/1_MA_median/MAmedian_err_all", "rb") as fp:   # Unpickling
    MAmedian_err_all = pickle.load(fp)
    
with open("/home/giuseppeditursi/Desktop/Respiration_from_SCG/2_Resp_Extraction/2_PSD_01/PSD01_err_all", "rb") as fp:   # Unpickling
    PSDonly_err_all = pickle.load(fp)
    
with open("/home/giuseppeditursi/Desktop/Respiration_from_SCG/2_Resp_Extraction/3_Adaptive_Filt/AdaptiveFilt_err_all", "rb") as fp:   # Unpickling
    AdaptiveFilt_err_all = pickle.load(fp)
    
with open("/home/giuseppeditursi/Desktop/Respiration_from_SCG/2_Resp_Extraction/4_Envelope/Envelope_err_all", "rb") as fp:   # Unpickling
    Envelope_err_all = pickle.load(fp)
    
with open("/home/giuseppeditursi/Desktop/Respiration_from_SCG/2_Resp_Extraction/5_Wavelets/Wavelets_resp_err_all", "rb") as fp:   # Unpickling
    Wavelets_resp_err_all = pickle.load(fp)
    
with open("/home/giuseppeditursi/Desktop/Respiration_from_SCG/2_Resp_Extraction/7_EMD/EMD_err_all", "rb") as fp:   # Unpickling
    EMD_err_all = pickle.load(fp)
    
with open("/home/giuseppeditursi/Desktop/Respiration_from_SCG/2_Resp_Extraction/9_TVF/TVF_err_all", "rb") as fp:   # Unpickling
    TVF_err_all = pickle.load(fp)

# %% [markdown]
# # COMPARISON

# %%
data = [ICA_err_all, MAmedian_err_all, PSDonly_err_all, AdaptiveFilt_err_all, Envelope_err_all, Wavelets_resp_err_all, EMD_err_all, TVF_err_all]

figure(figsize=(13, 8), dpi=80)
plt.boxplot(data, showfliers=True)
x = np.array([1,2,3,4,5,6,7,8])
my_xticks = ['ICA', 'MA_median','PSD_01','Adaptive_Filt','Envelope', 'Wavelets', 'EMD', 'TVF']
plt.xticks(x, my_xticks)
plt.ylabel('MAE (s)')
plt.title('SCG Respiration period algorithms comparison')
# Out:
# Text(0.5, 1.0, 'SCG Respiration period algorithms comparison')

# %%
data = [ICA_err_all, MAmedian_err_all, PSDonly_err_all, AdaptiveFilt_err_all, Envelope_err_all, Wavelets_resp_err_all, EMD_err_all, TVF_err_all]

figure(figsize=(13, 8), dpi=80)
plt.boxplot(data, showfliers=False)
x = np.array([1,2,3,4,5,6,7,8])
my_xticks = ['ICA', 'MA_median','PSD_01','Adaptive_Filt','Envelope', 'Wavelets', 'EMD', 'TVF']
plt.xticks(x, my_xticks)
plt.ylabel('MAE (s)')
plt.title('SCG Respiration period algorithms comparison')
# Out:
# Text(0.5, 1.0, 'SCG Respiration period algorithms comparison')
